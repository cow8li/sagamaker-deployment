# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %%
# Make sure that we use SageMaker 1.x
# !pip install sagemaker==1.72.0
# Out:
# Collecting sagemaker==1.72.0
#   Using cached sagemaker-1.72.0-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.19.4)
# Requirement already satisfied: scipy>=0.19.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.4.1)
# Requirement already satisfied: boto3>=1.14.12 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.16.37)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (3.14.0)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (3.1.0)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (0.1.5)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (20.7)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (0.3.3)
# Requirement already satisfied: botocore<1.20.0,>=1.19.37 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (1.19.37)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from botocore<1.20.0,>=1.19.37->boto3>=1.14.12->sagemaker==1.72.0) (1.25.11)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from botocore<1.20.0,>=1.19.37->boto3>=1.14.12->sagemaker==1.72.0) (2.8.1)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker==1.72.0) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from packaging>=20.0->sagemaker==1.72.0) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker==1.72.0) (1.15.0)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (3.14.0)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker==1.72.0) (1.15.0)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker==1.72.0) (1.15.0)
# Requirement already satisfied: botocore<1.20.0,>=1.19.37 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (1.19.37)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.19.4)
# Collecting smdebug-rulesconfig==0.1.4
#   Using cached smdebug_rulesconfig-0.1.4-py2.py3-none-any.whl (10 kB)
# Installing collected packages: smdebug-rulesconfig, sagemaker
#   Attempting uninstall: smdebug-rulesconfig
#     Found existing installation: smdebug-rulesconfig 1.0.0
#     Uninstalling smdebug-rulesconfig-1.0.0:
#       Successfully uninstalled smdebug-rulesconfig-1.0.0
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.19.0
#     Uninstalling sagemaker-2.19.0:
#       Successfully uninstalled sagemaker-2.19.0
# Successfully installed sagemaker-1.72.0 smdebug-rulesconfig-0.1.4
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p36/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2021-01-18 16:04:33--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  24.1MB/s    in 4.0s
#
# 2021-01-18 16:04:37 (19.9 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# 'The emotional powers and characters of Dominick and Eugene are the things that Hollywood doesn\'t make anymore. This is one of the most emotional, sensitive, and heart-felt movies that I have ever seen! Roy Liotta, Tom Hulce, and supporting actress Jamie Lee Curtis, deliver Oscar Winning caliber performances! There are not enough words to express how great this movie is. Sure, people who are not into sentimental movies may not care as much as the rest of us about Dominick and Eugene, but for the rest of us, this movie goes right to the heart and sole of compassion and humanity. You will never forget this film, EVER!<br /><br />*****SPOILERS BELOW*****<br /><br />The simple yet eloquent story is masterfully told. Eugene is a med-school intern who faces long hours and a demanding work load at the hospital. His fraternal twin brother Dominick (born 12 minutes earlier) is a little slow and awkward because of brain damage due to a victim of abuse by their father. (A heartbreaking moment when this is found out in the film that will leave you in tears!) Eugene (a.k.a "Geno") faces a painful dilemma. He must decide whether to finish medical school, which would mean accepting his residency in another city and leave Dominick (a.k.a "Nicky") behind, or forfeit the rest of his education to take care of him. Nicky helps pay his brother\'s med-school tuition by working as a trash collector.<br /><br />The questions of ethics, morals, and responsibilities are masterfully blended in this landmark movie. Just when Gino thinks Nicky might be making progress toward independence, Dominick turns around and winds up doing things like helping out a drug dealer, or tying to use a faulty cord that he finds at the dump on an electrical appliance.<br /><br />Larry, is "The Character" and Nicky\'s partner on his garbage route who fills gullible Dominick\'s head with all kinds of stories like Geno and Jennifer (his girlfriend, whom he is tutoring in Clinical Pharmacology) going to Atlantic City and gambling away all their money. But deep down, you can see that Larry cares for him. On their rounds, Nicky also befriends a little boy, whom we find out has also been beaten by his father. An end result is also tragic and the pain that you see on Nicky\'s face when it happens, speaks volumes.<br /><br />The sensitivity that the two brothers share for each other can not be overstated enough. All Nicky wants to do is be loved and look for acceptance in anyway he can. (i.e he goes to church, loves Hulk Hogan) Geno loves Nicky more than anything in the world. But can his brother become independent enough so that Geno can pursue his dream of becoming a doctor? A brilliant film that should have gotten tons more recognition than it deserved, but unfortunately came out around the same time as Rain Man, which dealt with a similar issue. However, I like Dominick and Eugene better because it has a far stronger emotional component. Be forewarned that this movie is aimed right at the tear-ducts, so have Kleenex handy! What a film!!!!'

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Read preprocessed data from cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Read features from cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

test_y = pd.DataFrame(test_y)
test_X = pd.DataFrame(test_X)

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

# pd.concat([test_y, test_X], axis=1).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)
pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating a hypertuned XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. As in the Boston Housing notebook, the first step is to create an estimator object which will be used as the *base* of your hyperparameter tuning job.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = sagemaker.estimator.Estimator(container, # The name of the training container
                                    role,      # The IAM role to use (our current role in this case)
                                    train_instance_count=1, # The number of instances to use for training
                                    train_instance_type='ml.m4.xlarge', # The type of instance ot use for training
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                        # Where to save the output (the model artifacts)
                                    sagemaker_session=session) # The current SageMaker session

# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.

xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# ### (TODO) Create the hyperparameter tuner
#
# Now that the base estimator has been set up we need to construct a hyperparameter tuner object which we will use to request SageMaker construct a hyperparameter tuning job.
#
# **Note:** Training a single sentiment analysis XGBoost model takes longer than training a Boston Housing XGBoost model so if you don't want the hyperparameter tuning job to take too long, make sure to not set the total number of models (jobs) too high.

# %%
# First, make sure to import the relevant objects used to construct the tuner
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner

# TODO: Create the hyperparameter tuner object

xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb, # The estimator object to use as the basis for the training jobs.
                                               objective_metric_name = 'validation:rmse', # The metric used to compare trained models.
                                               objective_type = 'Minimize', # Whether we wish to minimize or maximize the metric.
                                               max_jobs = 3, # The total number of models to train
                                               max_parallel_jobs = 3, # The number of models to train in parallel
                                               hyperparameter_ranges = {
                                                    'max_depth': IntegerParameter(3, 12),
                                                    'eta'      : ContinuousParameter(0.05, 0.5),
                                                    'min_child_weight': IntegerParameter(2, 8),
                                                    'subsample': ContinuousParameter(0.5, 0.9),
                                                    'gamma': ContinuousParameter(0, 10),
                                               })

# %% [markdown]
# ### Fit the hyperparameter tuner
#
# Now that the hyperparameter tuner object has been constructed, it is time to fit the various models and find the best performing model.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})

# %% [markdown]
# Remember that the tuning job is constructed and run in the background so if we want to see the progress of our training job we need to call the `wait()` method.

# %%
xgb_hyperparameter_tuner.wait()
# Out:
# ..................................................................................................................................................!

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've run our hyperparameter tuning job, it's time to see how well the best performing model actually performs. To do this we will use SageMaker's Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# Remember that in order to create a transformer object to perform the batch transform job, we need a trained estimator object. We can do that using the `attach()` method, creating an estimator object which is attached to the best trained job.

# %%
# TODO: Create a new estimator object attached to the best training job found during hyperparameter tuning

xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2021-01-18 17:15:43 Starting - Preparing the instances for training
# 2021-01-18 17:15:43 Downloading - Downloading input data
# 2021-01-18 17:15:43 Training - Training image download completed. Training in progress.
# 2021-01-18 17:15:43 Uploading - Uploading generated training model
# 2021-01-18 17:15:43 Completed - Training job completedArguments: train
# [2021-01-18:17:08:34:INFO] Running standalone xgboost training.
# [2021-01-18:17:08:34:INFO] Setting up HPO optimized metric to be : rmse
# [2021-01-18:17:08:34:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8424.41mb
# [2021-01-18:17:08:34:INFO] Determined delimiter of CSV input is ','
# [17:08:34] S3DistributionType set as FullyReplicated
# [17:08:36] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-01-18:17:08:36:INFO] Determined delimiter of CSV input is ','
# [17:08:36] S3DistributionType set as FullyReplicated
# [17:08:37] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [17:08:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=4
# [0]#011train-rmse:0.483698#011validation-rmse:0.484377
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [17:08:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=4
# [1]#011train-rmse:0.471386#011validation-rmse:0.472611
# [17:08:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=4
# [2]#011train-rmse:0.461973#011validation-rmse:0.463795
# [17:08:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=4
# [3]#011train-rmse:0.454477#011validation-rmse:0.456297
# [17:08:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=4
# [4]#011train-rmse:0.448252#011validation-rmse:0.450649
# [17:08:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=4
# [5]#011train-rmse:0.442042#011validation-rmse:0.445234
# [17:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=4
# [6]#011train-rmse:0.436544#011validation-rmse:0.43992
# [17:08:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [7]#011train-rmse:0.432532#011validation-rmse:0.435691
# [17:08:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [8]#011train-rmse:0.428576#011validation-rmse:0.431839
# [17:08:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [9]#011train-rmse:0.424855#011validation-rmse:0.428487
# [17:08:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=4
# [10]#011train-rmse:0.421383#011validation-rmse:0.42535
# [17:08:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=4
# [11]#011train-rmse:0.418198#011validation-rmse:0.422256
# [17:08:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [12]#011train-rmse:0.414836#011validation-rmse:0.419102
# [17:08:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [13]#011train-rmse:0.411893#011validation-rmse:0.416077
# [17:08:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=4
# [14]#011train-rmse:0.409277#011validation-rmse:0.413741
# [17:09:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [15]#011train-rmse:0.406531#011validation-rmse:0.41142
# [17:09:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=4
# [16]#011train-rmse:0.403983#011validation-rmse:0.409162
# [17:09:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=4
# [17]#011train-rmse:0.402064#011validation-rmse:0.407147
# [17:09:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [18]#011train-rmse:0.400083#011validation-rmse:0.405295
# [17:09:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=4
# [19]#011train-rmse:0.397578#011validation-rmse:0.403081
# [17:09:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=4
# [20]#011train-rmse:0.39501#011validation-rmse:0.40111
# [17:09:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=4
# [21]#011train-rmse:0.39286#011validation-rmse:0.399178
# [17:09:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 18 pruned nodes, max_depth=4
# [22]#011train-rmse:0.39115#011validation-rmse:0.397765
# [17:09:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=4
# [23]#011train-rmse:0.389174#011validation-rmse:0.395886
# [17:09:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [24]#011train-rmse:0.387466#011validation-rmse:0.394278
# [17:09:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=4
# [25]#011train-rmse:0.385753#011validation-rmse:0.392588
# [17:09:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=4
# [26]#011train-rmse:0.384225#011validation-rmse:0.391125
# [17:09:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=4
# [27]#011train-rmse:0.382638#011validation-rmse:0.389619
# [17:09:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [28]#011train-rmse:0.3812#011validation-rmse:0.388473
# [17:09:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=4
# [29]#011train-rmse:0.379514#011validation-rmse:0.386764
# [17:09:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=4
# [30]#011train-rmse:0.378096#011validation-rmse:0.385216
# [17:09:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=4
# [31]#011train-rmse:0.376799#011validation-rmse:0.384207
# [17:09:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=4
# [32]#011train-rmse:0.375263#011validation-rmse:0.382966
# [17:09:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=4
# [33]#011train-rmse:0.373872#011validation-rmse:0.381617
# [17:09:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=4
# [34]#011train-rmse:0.372405#011validation-rmse:0.380339
# [17:09:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [35]#011train-rmse:0.371177#011validation-rmse:0.379321
# [17:09:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [36]#011train-rmse:0.370071#011validation-rmse:0.378348
# [17:09:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [37]#011train-rmse:0.368943#011validation-rmse:0.377593
# [17:09:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=4
# [38]#011train-rmse:0.367478#011validation-rmse:0.376376
# [17:09:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=4
# [39]#011train-rmse:0.366322#011validation-rmse:0.375285
# [17:09:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=4
# [40]#011train-rmse:0.365036#011validation-rmse:0.374383
# [17:09:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=4
# [41]#011train-rmse:0.363928#011validation-rmse:0.373354
# [17:09:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=4
# [42]#011train-rmse:0.362802#011validation-rmse:0.372324
# [17:09:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=4
# [43]#011train-rmse:0.361342#011validation-rmse:0.371095
# [17:09:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=4
# [44]#011train-rmse:0.360476#011validation-rmse:0.370298
# [17:09:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [45]#011train-rmse:0.359569#011validation-rmse:0.369195
# [17:09:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=4
# [46]#011train-rmse:0.358678#011validation-rmse:0.368371
# [17:09:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=4
# [47]#011train-rmse:0.357675#011validation-rmse:0.367342
# [17:09:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=4
# [48]#011train-rmse:0.356705#011validation-rmse:0.366472
# [17:09:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [49]#011train-rmse:0.35581#011validation-rmse:0.365668
# [17:09:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=4
# [50]#011train-rmse:0.354971#011validation-rmse:0.364791
# [17:09:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [51]#011train-rmse:0.35411#011validation-rmse:0.363978
# [17:09:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=4
# [52]#011train-rmse:0.353207#011validation-rmse:0.363317
# [17:09:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=4
# [53]#011train-rmse:0.352474#011validation-rmse:0.36272
# [17:09:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=4
# [54]#011train-rmse:0.351553#011validation-rmse:0.3621
# [17:09:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [55]#011train-rmse:0.350737#011validation-rmse:0.361184
# [17:09:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=4
# [56]#011train-rmse:0.349689#011validation-rmse:0.360499
# [17:09:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [57]#011train-rmse:0.348929#011validation-rmse:0.359745
# [17:09:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [58]#011train-rmse:0.348201#011validation-rmse:0.359218
# [17:09:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=4
# [59]#011train-rmse:0.347458#011validation-rmse:0.358584
# [17:09:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=4
# [60]#011train-rmse:0.346826#011validation-rmse:0.357928
# [17:09:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=4
# [61]#011train-rmse:0.345872#011validation-rmse:0.357047
# [17:10:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [62]#011train-rmse:0.345196#011validation-rmse:0.356272
# [17:10:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [63]#011train-rmse:0.344522#011validation-rmse:0.355696
# [17:10:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [64]#011train-rmse:0.34397#011validation-rmse:0.355249
# [17:10:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=4
# [65]#011train-rmse:0.343505#011validation-rmse:0.354964
# [17:10:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=4
# [66]#011train-rmse:0.34278#011validation-rmse:0.354223
# [17:10:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [67]#011train-rmse:0.342104#011validation-rmse:0.353531
# [17:10:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [68]#011train-rmse:0.341545#011validation-rmse:0.353058
# [17:10:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [69]#011train-rmse:0.340951#011validation-rmse:0.352637
# [17:10:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=4
# [70]#011train-rmse:0.340288#011validation-rmse:0.352228
# [17:10:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=4
# [71]#011train-rmse:0.339686#011validation-rmse:0.351795
# [17:10:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [72]#011train-rmse:0.338983#011validation-rmse:0.351322
# [17:10:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=4
# [73]#011train-rmse:0.338241#011validation-rmse:0.350678
# [17:10:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [74]#011train-rmse:0.337604#011validation-rmse:0.350318
# [17:10:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=4
# [75]#011train-rmse:0.336853#011validation-rmse:0.349886
# [17:10:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=4
# [76]#011train-rmse:0.336033#011validation-rmse:0.349278
# [17:10:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=4
# [77]#011train-rmse:0.335199#011validation-rmse:0.348866
# [17:10:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=4
# [78]#011train-rmse:0.334575#011validation-rmse:0.348364
# [17:10:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [79]#011train-rmse:0.334062#011validation-rmse:0.347784
# [17:10:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [80]#011train-rmse:0.333491#011validation-rmse:0.347296
# [17:10:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=4
# [81]#011train-rmse:0.332951#011validation-rmse:0.347082
# [17:10:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [82]#011train-rmse:0.332369#011validation-rmse:0.346779
# [17:10:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [83]#011train-rmse:0.331868#011validation-rmse:0.346396
# [17:10:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [84]#011train-rmse:0.331413#011validation-rmse:0.346188
# [17:10:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [85]#011train-rmse:0.330915#011validation-rmse:0.345783
# [17:10:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [86]#011train-rmse:0.330297#011validation-rmse:0.345227
# [17:10:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [87]#011train-rmse:0.32976#011validation-rmse:0.344852
# [17:10:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [88]#011train-rmse:0.32925#011validation-rmse:0.34411
# [17:10:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [89]#011train-rmse:0.328649#011validation-rmse:0.343863
# [17:10:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [90]#011train-rmse:0.328121#011validation-rmse:0.34348
# [17:10:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [91]#011train-rmse:0.327725#011validation-rmse:0.343063
# [17:10:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [92]#011train-rmse:0.32728#011validation-rmse:0.342854
# [17:10:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [93]#011train-rmse:0.326855#011validation-rmse:0.342463
# [17:10:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [94]#011train-rmse:0.326355#011validation-rmse:0.341958
# [17:10:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=4
# [95]#011train-rmse:0.325885#011validation-rmse:0.341602
# [17:10:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [96]#011train-rmse:0.325506#011validation-rmse:0.341135
# [17:10:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [97]#011train-rmse:0.324909#011validation-rmse:0.340961
# [17:10:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=4
# [98]#011train-rmse:0.324422#011validation-rmse:0.340746
# [17:10:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [99]#011train-rmse:0.323952#011validation-rmse:0.340386
# [17:10:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=4
# [100]#011train-rmse:0.323492#011validation-rmse:0.340098
# [17:10:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [101]#011train-rmse:0.323146#011validation-rmse:0.339776
# [17:10:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [102]#011train-rmse:0.322825#011validation-rmse:0.33952
# [17:10:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=4
# [103]#011train-rmse:0.322249#011validation-rmse:0.339096
# [17:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [104]#011train-rmse:0.321859#011validation-rmse:0.338772
# [17:10:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [105]#011train-rmse:0.321384#011validation-rmse:0.338586
# [17:10:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [106]#011train-rmse:0.321055#011validation-rmse:0.338136
# [17:10:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [107]#011train-rmse:0.320759#011validation-rmse:0.33777
# [17:10:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [108]#011train-rmse:0.320316#011validation-rmse:0.337504
# [17:10:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=4
# [109]#011train-rmse:0.320009#011validation-rmse:0.337231
# [17:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=4
# [110]#011train-rmse:0.319519#011validation-rmse:0.336845
# [17:11:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [111]#011train-rmse:0.319179#011validation-rmse:0.336494
# [17:11:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [112]#011train-rmse:0.318806#011validation-rmse:0.336015
# [17:11:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [113]#011train-rmse:0.318382#011validation-rmse:0.335715
# [17:11:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [114]#011train-rmse:0.317944#011validation-rmse:0.335297
# [17:11:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=4
# [115]#011train-rmse:0.317516#011validation-rmse:0.335063
# [17:11:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [116]#011train-rmse:0.317188#011validation-rmse:0.334768
# [17:11:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [117]#011train-rmse:0.316784#011validation-rmse:0.334618
# [17:11:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=4
# [118]#011train-rmse:0.316399#011validation-rmse:0.334492
# [17:11:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [119]#011train-rmse:0.315927#011validation-rmse:0.334062
# [17:11:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [120]#011train-rmse:0.315605#011validation-rmse:0.333697
# [17:11:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [121]#011train-rmse:0.315245#011validation-rmse:0.333495
# [17:11:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [122]#011train-rmse:0.314879#011validation-rmse:0.333209
# [17:11:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=4
# [123]#011train-rmse:0.31445#011validation-rmse:0.332921
# [17:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [124]#011train-rmse:0.314073#011validation-rmse:0.332443
# [17:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [125]#011train-rmse:0.313733#011validation-rmse:0.332138
# [17:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=4
# [126]#011train-rmse:0.313269#011validation-rmse:0.331848
# [17:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [127]#011train-rmse:0.312956#011validation-rmse:0.331824
# [17:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [128]#011train-rmse:0.31258#011validation-rmse:0.331609
# [17:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=4
# [129]#011train-rmse:0.312018#011validation-rmse:0.331487
# [17:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [130]#011train-rmse:0.3117#011validation-rmse:0.331118
# [17:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [131]#011train-rmse:0.311281#011validation-rmse:0.330892
# [17:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 16 pruned nodes, max_depth=4
# [132]#011train-rmse:0.310999#011validation-rmse:0.330673
# [17:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=4
# [133]#011train-rmse:0.310559#011validation-rmse:0.330539
# [17:11:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [134]#011train-rmse:0.310269#011validation-rmse:0.330323
# [17:11:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [135]#011train-rmse:0.309969#011validation-rmse:0.330067
# [17:11:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [136]#011train-rmse:0.309531#011validation-rmse:0.329849
# [17:11:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [137]#011train-rmse:0.309152#011validation-rmse:0.329892
# [17:11:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [138]#011train-rmse:0.308856#011validation-rmse:0.329686
# [17:11:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 18 pruned nodes, max_depth=4
# [139]#011train-rmse:0.30858#011validation-rmse:0.32954
# [17:11:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=4
# [140]#011train-rmse:0.308342#011validation-rmse:0.32939
# [17:11:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=4
# [141]#011train-rmse:0.308085#011validation-rmse:0.329045
# [17:11:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [142]#011train-rmse:0.307819#011validation-rmse:0.328903
# [17:11:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [143]#011train-rmse:0.307534#011validation-rmse:0.328661
# [17:11:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [144]#011train-rmse:0.30724#011validation-rmse:0.328412
# [17:11:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [145]#011train-rmse:0.3069#011validation-rmse:0.32821
# [17:11:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [146]#011train-rmse:0.306586#011validation-rmse:0.328058
# [17:11:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [147]#011train-rmse:0.306232#011validation-rmse:0.327665
# [17:11:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=4
# [148]#011train-rmse:0.306003#011validation-rmse:0.32751
# [17:11:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [149]#011train-rmse:0.30573#011validation-rmse:0.32739
# [17:11:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=4
# [150]#011train-rmse:0.305394#011validation-rmse:0.327281
# [17:11:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [151]#011train-rmse:0.30514#011validation-rmse:0.327016
# [17:11:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [152]#011train-rmse:0.304905#011validation-rmse:0.327023
# [17:11:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [153]#011train-rmse:0.304716#011validation-rmse:0.326752
# [17:11:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [154]#011train-rmse:0.304468#011validation-rmse:0.326697
# [17:11:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [155]#011train-rmse:0.304137#011validation-rmse:0.326642
# [17:11:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [156]#011train-rmse:0.303832#011validation-rmse:0.326497
# [17:12:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [157]#011train-rmse:0.30357#011validation-rmse:0.326251
# [17:12:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=4
# [158]#011train-rmse:0.303168#011validation-rmse:0.326055
# [17:12:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=4
# [159]#011train-rmse:0.302877#011validation-rmse:0.325915
# [17:12:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 16 pruned nodes, max_depth=4
# [160]#011train-rmse:0.302631#011validation-rmse:0.325692
# [17:12:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [161]#011train-rmse:0.302316#011validation-rmse:0.325674
# [17:12:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [162]#011train-rmse:0.302095#011validation-rmse:0.325667
# [17:12:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [163]#011train-rmse:0.301827#011validation-rmse:0.325554
# [17:12:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [164]#011train-rmse:0.301605#011validation-rmse:0.325229
# [17:12:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [165]#011train-rmse:0.301324#011validation-rmse:0.325024
# [17:12:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [166]#011train-rmse:0.30104#011validation-rmse:0.324944
# [17:12:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [167]#011train-rmse:0.300761#011validation-rmse:0.324766
# [17:12:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [168]#011train-rmse:0.300516#011validation-rmse:0.324484
# [17:12:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [169]#011train-rmse:0.30026#011validation-rmse:0.324388
# [17:12:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [170]#011train-rmse:0.300006#011validation-rmse:0.324347
# [17:12:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [171]#011train-rmse:0.29977#011validation-rmse:0.324196
# [17:12:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [172]#011train-rmse:0.299567#011validation-rmse:0.323865
# [17:12:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [173]#011train-rmse:0.299289#011validation-rmse:0.323589
# [17:12:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [174]#011train-rmse:0.298999#011validation-rmse:0.323346
# [17:12:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [175]#011train-rmse:0.298819#011validation-rmse:0.323256
# [17:12:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [176]#011train-rmse:0.298602#011validation-rmse:0.323024
# [17:12:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=4
# [177]#011train-rmse:0.298345#011validation-rmse:0.322739
# [17:12:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [178]#011train-rmse:0.298083#011validation-rmse:0.322552
# [17:12:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [179]#011train-rmse:0.297889#011validation-rmse:0.322421
# [17:12:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=4
# [180]#011train-rmse:0.297408#011validation-rmse:0.321949
# [17:12:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [181]#011train-rmse:0.297195#011validation-rmse:0.321774
# [17:12:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [182]#011train-rmse:0.296932#011validation-rmse:0.321637
# [17:12:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [183]#011train-rmse:0.296751#011validation-rmse:0.321492
# [17:12:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [184]#011train-rmse:0.296536#011validation-rmse:0.321297
# [17:12:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [185]#011train-rmse:0.296196#011validation-rmse:0.321071
# [17:12:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [186]#011train-rmse:0.295995#011validation-rmse:0.321089
# [17:12:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [187]#011train-rmse:0.29578#011validation-rmse:0.321016
# [17:12:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=4
# [188]#011train-rmse:0.295228#011validation-rmse:0.320932
# [17:12:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [189]#011train-rmse:0.294999#011validation-rmse:0.320698
# [17:12:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [190]#011train-rmse:0.294737#011validation-rmse:0.320482
# [17:12:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 16 pruned nodes, max_depth=4
# [191]#011train-rmse:0.29449#011validation-rmse:0.320423
# [17:12:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [192]#011train-rmse:0.294282#011validation-rmse:0.320265
# [17:12:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [193]#011train-rmse:0.294087#011validation-rmse:0.320246
# [17:12:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [194]#011train-rmse:0.29383#011validation-rmse:0.320016
# [17:12:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=4
# [195]#011train-rmse:0.293464#011validation-rmse:0.319869
# [17:12:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [196]#011train-rmse:0.293236#011validation-rmse:0.319783
# [17:12:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=4
# [197]#011train-rmse:0.29307#011validation-rmse:0.319646
# [17:12:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [198]#011train-rmse:0.292859#011validation-rmse:0.319537
# [17:12:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [199]#011train-rmse:0.292581#011validation-rmse:0.319564
# [17:12:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [200]#011train-rmse:0.292422#011validation-rmse:0.319382
# [17:12:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [201]#011train-rmse:0.292159#011validation-rmse:0.319236
# [17:12:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=4
# [202]#011train-rmse:0.291949#011validation-rmse:0.31913
# [17:12:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [203]#011train-rmse:0.29176#011validation-rmse:0.318989
# [17:12:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [204]#011train-rmse:0.29153#011validation-rmse:0.31874
# [17:13:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [205]#011train-rmse:0.291383#011validation-rmse:0.318719
# [17:13:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [206]#011train-rmse:0.291165#011validation-rmse:0.318526
# [17:13:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [207]#011train-rmse:0.290886#011validation-rmse:0.318385
# [17:13:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [208]#011train-rmse:0.290695#011validation-rmse:0.318223
# [17:13:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [209]#011train-rmse:0.290546#011validation-rmse:0.318144
# [17:13:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [210]#011train-rmse:0.290312#011validation-rmse:0.318065
# [17:13:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=4
# [211]#011train-rmse:0.289985#011validation-rmse:0.317913
# [17:13:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [212]#011train-rmse:0.289749#011validation-rmse:0.317811
# [17:13:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [213]#011train-rmse:0.289425#011validation-rmse:0.317849
# [17:13:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [214]#011train-rmse:0.2891#011validation-rmse:0.317734
# [17:13:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=4
# [215]#011train-rmse:0.288839#011validation-rmse:0.31758
# [17:13:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [216]#011train-rmse:0.288671#011validation-rmse:0.317567
# [17:13:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [217]#011train-rmse:0.288523#011validation-rmse:0.317381
# [17:13:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=4
# [218]#011train-rmse:0.288264#011validation-rmse:0.317277
# [17:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [219]#011train-rmse:0.28812#011validation-rmse:0.317274
# [17:13:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [220]#011train-rmse:0.287915#011validation-rmse:0.317186
# [17:13:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [221]#011train-rmse:0.287767#011validation-rmse:0.317178
# [17:13:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [222]#011train-rmse:0.287573#011validation-rmse:0.317021
# [17:13:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [223]#011train-rmse:0.287401#011validation-rmse:0.316873
# [17:13:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [224]#011train-rmse:0.287102#011validation-rmse:0.316605
# [17:13:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [225]#011train-rmse:0.286889#011validation-rmse:0.316516
# [17:13:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [226]#011train-rmse:0.286672#011validation-rmse:0.316494
# [17:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [227]#011train-rmse:0.28641#011validation-rmse:0.316348
# [17:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [228]#011train-rmse:0.286176#011validation-rmse:0.316234
# [17:13:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [229]#011train-rmse:0.285984#011validation-rmse:0.316071
# [17:13:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [230]#011train-rmse:0.285824#011validation-rmse:0.316119
# [17:13:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [231]#011train-rmse:0.285616#011validation-rmse:0.315989
# [17:13:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [232]#011train-rmse:0.285397#011validation-rmse:0.315929
# [17:13:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [233]#011train-rmse:0.285236#011validation-rmse:0.315828
# [17:13:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [234]#011train-rmse:0.285143#011validation-rmse:0.315713
# [17:13:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [235]#011train-rmse:0.28501#011validation-rmse:0.315889
# [17:13:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [236]#011train-rmse:0.284824#011validation-rmse:0.315923
# [17:13:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [237]#011train-rmse:0.284558#011validation-rmse:0.315801
# [17:13:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [238]#011train-rmse:0.284387#011validation-rmse:0.315746
# [17:13:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [239]#011train-rmse:0.284097#011validation-rmse:0.315633
# [17:13:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [240]#011train-rmse:0.283926#011validation-rmse:0.31566
# [17:13:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [241]#011train-rmse:0.283694#011validation-rmse:0.315638
# [17:13:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [242]#011train-rmse:0.283502#011validation-rmse:0.31544
# [17:13:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=4
# [243]#011train-rmse:0.283387#011validation-rmse:0.315375
# [17:13:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [244]#011train-rmse:0.283201#011validation-rmse:0.315228
# [17:13:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [245]#011train-rmse:0.28302#011validation-rmse:0.315061
# [17:13:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [246]#011train-rmse:0.282775#011validation-rmse:0.314913
# [17:13:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=4
# [247]#011train-rmse:0.282631#011validation-rmse:0.314919
# [17:13:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [248]#011train-rmse:0.282449#011validation-rmse:0.314905
# [17:13:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [249]#011train-rmse:0.282216#011validation-rmse:0.314907
# [17:13:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 12 pruned nodes, max_depth=3
# [250]#011train-rmse:0.282046#011validation-rmse:0.314889
# [17:13:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [251]#011train-rmse:0.281934#011validation-rmse:0.314754
# [17:13:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=4
# [252]#011train-rmse:0.281643#011validation-rmse:0.314598
# [17:14:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [253]#011train-rmse:0.281602#011validation-rmse:0.314627
# [17:14:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [254]#011train-rmse:0.281511#011validation-rmse:0.314544
# [17:14:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [255]#011train-rmse:0.28131#011validation-rmse:0.314429
# [17:14:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [256]#011train-rmse:0.281115#011validation-rmse:0.31439
# [17:14:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [257]#011train-rmse:0.280938#011validation-rmse:0.314443
# [17:14:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=4
# [258]#011train-rmse:0.28072#011validation-rmse:0.314441
# [17:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 12 pruned nodes, max_depth=2
# [259]#011train-rmse:0.280655#011validation-rmse:0.314546
# [17:14:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [260]#011train-rmse:0.28054#011validation-rmse:0.314512
# [17:14:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [261]#011train-rmse:0.280395#011validation-rmse:0.31428
# [17:14:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [262]#011train-rmse:0.280245#011validation-rmse:0.314236
# [17:14:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [263]#011train-rmse:0.280034#011validation-rmse:0.314324
# [17:14:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [264]#011train-rmse:0.279878#011validation-rmse:0.314254
# [17:14:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=3
# [265]#011train-rmse:0.279587#011validation-rmse:0.31426
# [17:14:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [266]#011train-rmse:0.279388#011validation-rmse:0.31419
# [17:14:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [267]#011train-rmse:0.279269#011validation-rmse:0.314252
# [17:14:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=4
# [268]#011train-rmse:0.279029#011validation-rmse:0.31397
# [17:14:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [269]#011train-rmse:0.278889#011validation-rmse:0.31373
# [17:14:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [270]#011train-rmse:0.278692#011validation-rmse:0.313603
# [17:14:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [271]#011train-rmse:0.278634#011validation-rmse:0.313424
# [17:14:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [272]#011train-rmse:0.278336#011validation-rmse:0.313149
# [17:14:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [273]#011train-rmse:0.278201#011validation-rmse:0.313228
# [17:14:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [274]#011train-rmse:0.278105#011validation-rmse:0.313137
# [17:14:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 14 pruned nodes, max_depth=2
# [275]#011train-rmse:0.27801#011validation-rmse:0.313054
# [17:14:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [276]#011train-rmse:0.277847#011validation-rmse:0.31299
# [17:14:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [277]#011train-rmse:0.277716#011validation-rmse:0.313019
# [17:14:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [278]#011train-rmse:0.277564#011validation-rmse:0.312939
# [17:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [279]#011train-rmse:0.277412#011validation-rmse:0.31303
# [17:14:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 8 pruned nodes, max_depth=2
# [280]#011train-rmse:0.277357#011validation-rmse:0.313069
# [17:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [281]#011train-rmse:0.277254#011validation-rmse:0.313068
# [17:14:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 16 pruned nodes, max_depth=2
# [282]#011train-rmse:0.277206#011validation-rmse:0.313056
# [17:14:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [283]#011train-rmse:0.277088#011validation-rmse:0.313116
# [17:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [284]#011train-rmse:0.27691#011validation-rmse:0.31302
# [17:14:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 16 pruned nodes, max_depth=4
# [285]#011train-rmse:0.276736#011validation-rmse:0.312935
# [17:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 6 pruned nodes, max_depth=2
# [286]#011train-rmse:0.276661#011validation-rmse:0.31291
# [17:14:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 8 pruned nodes, max_depth=0
# [287]#011train-rmse:0.276643#011validation-rmse:0.312908
# [17:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 16 pruned nodes, max_depth=1
# [288]#011train-rmse:0.276625#011validation-rmse:0.312934
# [17:14:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 10 pruned nodes, max_depth=2
# [289]#011train-rmse:0.276554#011validation-rmse:0.312916
# [17:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=4
# [290]#011train-rmse:0.276298#011validation-rmse:0.312847
# [17:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=4
# [291]#011train-rmse:0.276125#011validation-rmse:0.312688
# [17:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [292]#011train-rmse:0.276009#011validation-rmse:0.312616
# [17:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [293]#011train-rmse:0.275902#011validation-rmse:0.312575
# [17:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [294]#011train-rmse:0.27579#011validation-rmse:0.312422
# [17:14:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 8 pruned nodes, max_depth=1
# [295]#011train-rmse:0.27574#011validation-rmse:0.312375
# [17:14:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [296]#011train-rmse:0.275601#011validation-rmse:0.312263
# [17:14:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [297]#011train-rmse:0.275469#011validation-rmse:0.312248
# [17:14:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 18 pruned nodes, max_depth=4
# [298]#011train-rmse:0.275322#011validation-rmse:0.312226
# [17:14:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [299]#011train-rmse:0.275235#011validation-rmse:0.312132
# [17:15:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [300]#011train-rmse:0.275198#011validation-rmse:0.312126
# [17:15:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 12 pruned nodes, max_depth=3
# [301]#011train-rmse:0.275071#011validation-rmse:0.312043
# [17:15:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 6 pruned nodes, max_depth=2
# [302]#011train-rmse:0.275005#011validation-rmse:0.312058
# [17:15:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 8 pruned nodes, max_depth=1
# [303]#011train-rmse:0.274969#011validation-rmse:0.312073
# [17:15:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 8 pruned nodes, max_depth=1
# [304]#011train-rmse:0.27493#011validation-rmse:0.31209
# [17:15:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [305]#011train-rmse:0.27477#011validation-rmse:0.312018
# [17:15:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 8 pruned nodes, max_depth=2
# [306]#011train-rmse:0.274696#011validation-rmse:0.311899
# [17:15:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [307]#011train-rmse:0.274591#011validation-rmse:0.311869
# [17:15:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [308]#011train-rmse:0.274492#011validation-rmse:0.311812
# [17:15:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [309]#011train-rmse:0.274407#011validation-rmse:0.311813
# [17:15:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [310]#011train-rmse:0.274274#011validation-rmse:0.31186
# [17:15:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [311]#011train-rmse:0.274211#011validation-rmse:0.311808
# [17:15:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [312]#011train-rmse:0.274163#011validation-rmse:0.311814
# [17:15:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [313]#011train-rmse:0.274058#011validation-rmse:0.311778
# [17:15:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [314]#011train-rmse:0.273932#011validation-rmse:0.311573
# [17:15:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [315]#011train-rmse:0.273877#011validation-rmse:0.311589
# [17:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 10 pruned nodes, max_depth=3
# [316]#011train-rmse:0.273812#011validation-rmse:0.311677
# [17:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 12 pruned nodes, max_depth=2
# [317]#011train-rmse:0.273732#011validation-rmse:0.311651
# [17:15:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=4
# [318]#011train-rmse:0.273501#011validation-rmse:0.311703
# [17:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [319]#011train-rmse:0.273499#011validation-rmse:0.311703
# [17:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 18 pruned nodes, max_depth=1
# [320]#011train-rmse:0.273471#011validation-rmse:0.311664
# [17:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [321]#011train-rmse:0.273354#011validation-rmse:0.311648
# [17:15:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [322]#011train-rmse:0.273185#011validation-rmse:0.311637
# [17:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [323]#011train-rmse:0.273007#011validation-rmse:0.311678
# [17:15:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [324]#011train-rmse:0.272847#011validation-rmse:0.311591
# Stopping. Best iteration:
# [314]#011train-rmse:0.273932#011validation-rmse:0.311573
#
# Training seconds: 488
# Billable seconds: 488

# %% [markdown]
# Now that we have an estimator object attached to the correct training job, we can proceed as we normally would and create a transformer object.

# %%
# TODO: Create a transformer object from the attached estimator. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.

xgb_transformer = xgb_attached.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# ..............................2021-01-18T17:51:47.100:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# Arguments: serve
# [2021-01-18 17:51:46 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2021-01-18 17:51:46 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2021-01-18 17:51:46 +0000] [1] [INFO] Using worker: gevent
# [2021-01-18 17:51:46 +0000] [36] [INFO] Booting worker with pid: 36
# [2021-01-18 17:51:47 +0000] [37] [INFO] Booting worker with pid: 37
# [2021-01-18 17:51:47 +0000] [38] [INFO] Booting worker with pid: 38
# [2021-01-18:17:51:47:INFO] Model loaded successfully for worker : 36
# [2021-01-18:17:51:47:INFO] Model loaded successfully for worker : 37
# [2021-01-18 17:51:47 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-01-18:17:51:47:INFO] Model loaded successfully for worker : 38
# Arguments: serve
# [2021-01-18 17:51:46 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2021-01-18 17:51:46 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2021-01-18 17:51:46 +0000] [1] [INFO] Using worker: gevent
# [2021-01-18 17:51:46 +0000] [36] [INFO] Booting worker with pid: 36
# [2021-01-18 17:51:47 +0000] [37] [INFO] Booting worker with pid: 37
# [2021-01-18 17:51:47 +0000] [38] [INFO] Booting worker with pid: 38
# [2021-01-18:17:51:47:INFO] Model loaded successfully for worker : 36
# [2021-01-18:17:51:47:INFO] Model loaded successfully for worker : 37
# [2021-01-18 17:51:47 +0000] [39] [INFO] Booting worker with pid: 39
# [2021-01-18:17:51:47:INFO] Model loaded successfully for worker : 38
# [2021-01-18:17:51:47:INFO] Model loaded successfully for worker : 39
# [2021-01-18:17:51:47:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:47:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:47:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:47:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:47:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:47:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:47:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:47:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:47:INFO] Model loaded successfully for worker : 39
# [2021-01-18:17:51:47:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:47:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:47:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:47:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:47:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:47:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:47:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:47:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:50:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:50:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:50:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:50:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:50:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:50:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:50:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:50:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:50:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:50:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:50:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:50:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:50:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:50:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:50:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:50:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:54:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:54:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:55:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:55:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:54:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:54:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:55:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:55:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:55:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:55:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:55:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:55:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:55:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:55:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:55:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:55:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:57:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:57:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:57:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:57:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:57:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:57:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:57:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:57:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:57:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:57:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:57:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:57:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:57:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:57:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:57:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:57:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:59:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:59:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:59:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:59:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:59:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:59:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:51:59:INFO] Sniff delimiter as ','
# [2021-01-18:17:51:59:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:00:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:00:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:00:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:00:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:00:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:00:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:00:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:00:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:02:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:02:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:02:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:02:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:02:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:02:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:02:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:02:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:04:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:04:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:04:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:04:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:05:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:05:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:04:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:04:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:04:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:04:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:05:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:05:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:05:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:05:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:05:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:05:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:07:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:07:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:07:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:07:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:07:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:07:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:07:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:07:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:07:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:07:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:07:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:07:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:07:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:07:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:07:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:07:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:09:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:09:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:09:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:09:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:09:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:09:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:09:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:10:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:10:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:09:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:09:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:09:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:09:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:09:INFO] Determined delimiter of CSV input is ','
# [2021-01-18:17:52:10:INFO] Sniff delimiter as ','
# [2021-01-18:17:52:10:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-651844727492/xgboost-210118-1704-002-1fcc87d6-2021-01-18-17-46-46-520/test.csv.out to ../data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.86976

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
import os
data_dir = '../data/xgboost'
cache_dir = os.path.join("../cache", "sentiment_analysis")

# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
# Out:
# rm: cannot remove ‘../data/xgboost/*’: No such file or directory
# rmdir: failed to remove ‘../data/xgboost’: No such file or directory
